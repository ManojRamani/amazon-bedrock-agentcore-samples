# %% [markdown]
# ## Agent-Based Code Execution using Amazon AgentCore Bedrock Code Interpreter- Tutorial(Strands)
# This tutorial demonstrates how to create an AI agent that validates answers through code execution using Python. We use Amazon Bedrock AgentCore Code Interpreter to run code that is generated by the LLM
#
# This tutorial demonstrates how to use AgentCore Bedrock Code Interpreter to:
# 1. Set up a sandbox environment
# 2. Configure a strands based agent that generated code based on the user query
# 3. Execute code in a sandbox environment using Code Interpreter
# 4. Display the results back to the user
#
# ## Prerequisites
# - AWS account with Bedrock AgentCore Code Interpreter access
# - You have the necessary IAM permissions to create and manage code interpreter resources
# - Required Python packages installed(including boto3, bedrock-agentcore & strands)
# - IAM role should have permissions to invoke models on Amazon Bedrock
#  - Access to Claude 3.7 Sonnet model in the US Oregon (us-west-2) region (default model for Strands SDK)
#
# ## Your IAM execution role should have the following IAM policy attached

# %% [markdown]
# ~~~ {
# "Version": "2012-10-17",
# "Statement": [
#     {
#         "Effect": "Allow",
#         "Action": [
#             "bedrock-agentcore:CreateCodeInterpreter",
#             "bedrock-agentcore:StartCodeInterpreterSession",
#             "bedrock-agentcore:InvokeCodeInterpreter",
#             "bedrock-agentcore:StopCodeInterpreterSession",
#             "bedrock-agentcore:DeleteCodeInterpreter",
#             "bedrock-agentcore:ListCodeInterpreters",
#             "bedrock-agentcore:GetCodeInterpreter"
#         ],
#         "Resource": "*"
#     },
#     {
#         "Effect": "Allow",
#         "Action": [
#             "logs:CreateLogGroup",
#             "logs:CreateLogStream",
#             "logs:PutLogEvents"
#         ],
#         "Resource": "arn:aws:logs:*:*:log-group:/aws/bedrock-agentcore/code-interpreter*"
#     }
# ]
# }

# %% [markdown]
# ## How it works
#
# The code execution sandbox enables agents to safely process user queries by creating an isolated environment with a code interpreter, shell, and file system. After a Large Language Model helps with tool selection, code is executed within this session, before being returned to the user or Agent for synthesis.
#
# ![architecture local](code-interpreter.png)

# %% [markdown]
# ## 1. Setting Up the Environment
#
# First, let's import the necessary libraries and initialize our Code Interpreter session.

# %%
# !pip install --upgrade -r requirements.txt
# Out:
# Requirement already satisfied: boto3 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (1.40.50)
# Requirement already satisfied: bedrock-agentcore in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: strands-agents>=0.1.8 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.12.0)
# Requirement already satisfied: strands-agents-tools>=0.1.6 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.2.11)
# Requirement already satisfied: langchain-aws in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.2.35)
# Requirement already satisfied: langchain in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (0.3.27)
# Requirement already satisfied: botocore<1.41.0,>=1.40.50 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from boto3->-r requirements.txt (line 1)) (1.40.50)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from boto3->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from boto3->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.50->boto3->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.50->boto3->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: six>=1.5 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.50->boto3->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from bedrock-agentcore->-r requirements.txt (line 2)) (2.12.0)
# Requirement already satisfied: starlette>=0.46.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from bedrock-agentcore->-r requirements.txt (line 2)) (0.48.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from bedrock-agentcore->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: uvicorn>=0.34.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from bedrock-agentcore->-r requirements.txt (line 2)) (0.37.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore->-r requirements.txt (line 2)) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.0.0->bedrock-agentcore->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.17.0)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.37.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.58b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.37.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents>=0.1.8->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: anyio>=4.5 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.58b0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.58b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.58b0)
# Requirement already satisfied: packaging>=18.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from opentelemetry-instrumentation==0.58b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (3.13.0)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.26.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2.8)
# Requirement already satisfied: wcwidth in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.37.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.76 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain-aws->-r requirements.txt (line 5)) (0.3.79)
# Requirement already satisfied: numpy<3,>=1.26.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain-aws->-r requirements.txt (line 5)) (2.3.3)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (0.4.34)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (6.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<0.4.0,>=0.3.76->langchain-aws->-r requirements.txt (line 5)) (0.25.0)
# Requirement already satisfied: httpcore==1.* in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 6)) (0.3.11)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from langchain->-r requirements.txt (line 6)) (2.0.44)
# Requirement already satisfied: greenlet>=1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 6)) (3.2.4)
# Requirement already satisfied: sniffio>=1.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (0.27.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools>=0.1.6->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents>=0.1.8->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: click>=7.0 in /home/mjramani/projects/agents_hub/AgentCore/amazon-bedrock-agentcore-samples/.venv/lib/python3.12/site-packages (from uvicorn>=0.34.2->bedrock-agentcore->-r requirements.txt (line 2)) (8.3.0)

# %%
from bedrock_agentcore.tools.code_interpreter_client import code_session
from strands import Agent, tool
import json
from typing import Dict, Any, List

# %% [markdown]
# ## 2.System Prompt Definition
# Define the behavior and capabilities of the AI assistant. We instruct our assistant to always validate answers through code execution and data based reasoning.

# %%
SYSTEM_PROMPT = """You are a helpful AI assistant that validates all answers through code execution.

VALIDATION PRINCIPLES:
1. When making claims about code, algorithms, or calculations - write code to verify them
2. Use execute_python to test mathematical calculations, algorithms, and logic
3. Create test scripts to validate your understanding before giving answers
4. Always show your work with actual code execution
5. If uncertain, explicitly state limitations and validate what you can

APPROACH:
- If asked about a programming concept, implement it in code to demonstrate
- If asked for calculations, compute them programmatically AND show the code
- If implementing algorithms, include test cases to prove correctness
- Document your validation process for transparency
- The sandbox maintains state between executions, so you can refer to previous results

TOOL AVAILABLE:
- execute_python: Run Python code and see output

RESPONSE FORMAT: The execute_python tool returns a JSON response with:
- sessionId: The sandbox session ID
- id: Request ID
- isError: Boolean indicating if there was an error
- content: Array of content objects with type and text/data
- structuredContent: For code execution, includes stdout, stderr, exitCode, executionTime"""

# %% [markdown]
# ## 3.Code Execution Tool Definition
# Next we define the function as tool that will be used by the Agent as tool, to run code in the code sandbox. We use the @tool decorator to annotate the function as a custom tool for the Agent.
#
# Within an active code interpreter session, you can execute code in supported languages (Python, JavaScript), access libraries based on your dependencies configuration, generate visualizations, and maintain state between executions.

# %%
@tool
def execute_python(code: str, description: str = "") -> str:
    """Execute Python code in the sandbox."""
    
    if description:
        code = f"# {description}\n{code}"
    
    print(f"\n Generated Code: {code}")
    
    with code_session("us-west-2") as code_client:
        response = code_client.invoke("executeCode", {
            "code": code,
            "language": "python",
            "clearContext": False
        })
    
    for event in response["stream"]:
        return json.dumps(event["result"])

# %% [markdown]
# ## 4. Agent Configuration
# We create and configure an agent using the Strands SDK.We provide it the system prompt and the tool we defined above to execute generate code

# %%
agent = Agent(
    tools=[execute_python],
    system_prompt=SYSTEM_PROMPT,
    callback_handler=None
)

# %% [markdown]
# ## 5. Query Definition
# Define a sample query to test the agent with code execution capabilities

# %%
# query = "Tell me the largest random prime number between 1 and 100, which is less than 84 and more that 9"


# query = "I have a home valued at 500 k, i have 125k that i can put as down payment and in the market to shop for a mortgage. I have two loan offers - a 15 year term at 3.4% rate of interest and a 30 year term at 2.75% rate of interest. Which loan offer is more suitable for me ?"

query = "I have a home valued at 500 k, i have 125k that i can put as down payment and in the market to shop for a mortgage. I have two loan offers - a 15 year term at 3.4% rate of interest and a 30 year term at 2.75% rate of interest. Which loan offer is more suitable for me. Make sure to list out all the formulae you used for calculations ?"

# %% [markdown]
# ## 6. Agent Invocation and Response Processing
# We invoke the agent with our query and process the agent's response
#
#
# Note: Async execution requires running in an async environment

# %%
try:
    response_text = ""
    async for event in agent.stream_async(query):
        if "data" in event:
            chunk = event["data"]
            response_text += chunk
            print(chunk, end="")
except Exception as e:
    print(f"Error occurred: {str(e)}")
# Out:
# I'll help you analyze both mortgage offers by calculating the key financial metrics for each option. Let me break down the calculations step by step.
#  Generated Code: import math
#
# # Given information
# home_value = 500000
# down_payment = 125000
# loan_amount = home_value - down_payment
#
# print(f"Home Value: ${home_value:,}")
# print(f"Down Payment: ${down_payment:,}")
# print(f"Loan Amount: ${loan_amount:,}")
# print(f"Down Payment Percentage: {(down_payment/home_value)*100:.1f}%")
# Now let me calculate the monthly payments for both loan options using the standard mortgage payment formula:
#  Generated Code: # Loan Option 1: 15-year term at 3.4% interest
# term_1 = 15  # years
# annual_rate_1 = 3.4  # percent
# monthly_rate_1 = annual_rate_1 / 100 / 12  # convert to monthly decimal rate
# num_payments_1 = term_1 * 12  # total number of monthly payments
#
# # Loan Option 2: 30-year term at 2.75% interest
# term_2 = 30  # years
# annual_rate_2 = 2.75  # percent
# monthly_rate_2 = annual_rate_2 / 100 / 12  # convert to monthly decimal rate
# num_payments_2 = term_2 * 12  # total number of monthly payments
#
# print("LOAN PARAMETERS:")
# print(f"Option 1 - 15-year loan:")
# print(f"  Annual Interest Rate: {annual_rate_1}%")
# print(f"  Monthly Interest Rate: {monthly_rate_1:.6f}")
# print(f"  Number of Payments: {num_payments_1}")
# print()
# print(f"Option 2 - 30-year loan:")
# print(f"  Annual Interest Rate: {annual_rate_2}%")
# print(f"  Monthly Interest Rate: {monthly_rate_2:.6f}")
# print(f"  Number of Payments: {num_payments_2}")
# Now I'll calculate the monthly payment using the standard mortgage payment formula:
#
# **Monthly Payment Formula: M = P × [r(1+r)^n] / [(1+r)^n - 1]**
#
# Where:
# - M = Monthly payment
# - P = Principal loan amount
# - r = Monthly interest rate (annual rate ÷ 12)
# - n = Total number of payments (years × 12)
#  Generated Code: # Monthly Payment Formula: M = P * [r(1+r)^n] / [(1+r)^n - 1]
#
# def calculate_monthly_payment(principal, monthly_rate, num_payments):
#     """Calculate monthly mortgage payment"""
#     if monthly_rate == 0:
#         return principal / num_payments
#
#     numerator = monthly_rate * (1 + monthly_rate) ** num_payments
#     denominator = (1 + monthly_rate) ** num_payments - 1
#     monthly_payment = principal * (numerator / denominator)
#     return monthly_payment
#
# # Calculate monthly payments for both options
# monthly_payment_1 = calculate_monthly_payment(loan_amount, monthly_rate_1, num_payments_1)
# monthly_payment_2 = calculate_monthly_payment(loan_amount, monthly_rate_2, num_payments_2)
#
# print("MONTHLY PAYMENT CALCULATIONS:")
# print(f"\nOption 1 (15-year at 3.4%):")
# print(f"Formula: M = ${loan_amount:,} × [{monthly_rate_1:.6f}(1+{monthly_rate_1:.6f})^{num_payments_1}] / [(1+{monthly_rate_1:.6f})^{num_payments_1} - 1]")
# print(f"Monthly Payment: ${monthly_payment_1:,.2f}")
#
# print(f"\nOption 2 (30-year at 2.75%):")
# print(f"Formula: M = ${loan_amount:,} × [{monthly_rate_2:.6f}(1+{monthly_rate_2:.6f})^{num_payments_2}] / [(1+{monthly_rate_2:.6f})^{num_payments_2} - 1]")
# print(f"Monthly Payment: ${monthly_payment_2:,.2f}")
#
# print(f"\nDifference in Monthly Payment: ${monthly_payment_1 - monthly_payment_2:,.2f}")
# Let me redefine all variables and calculate the monthly payments:
#  Generated Code: # Redefine all variables
# home_value = 500000
# down_payment = 125000
# loan_amount = home_value - down_payment
#
# # Loan Option 1: 15-year term at 3.4% interest
# term_1 = 15
# annual_rate_1 = 3.4
# monthly_rate_1 = annual_rate_1 / 100 / 12
# num_payments_1 = term_1 * 12
#
# # Loan Option 2: 30-year term at 2.75% interest
# term_2 = 30
# annual_rate_2 = 2.75
# monthly_rate_2 = annual_rate_2 / 100 / 12
# num_payments_2 = term_2 * 12
#
# def calculate_monthly_payment(principal, monthly_rate, num_payments):
#     """Calculate monthly mortgage payment"""
#     if monthly_rate == 0:
#         return principal / num_payments
#
#     numerator = monthly_rate * (1 + monthly_rate) ** num_payments
#     denominator = (1 + monthly_rate) ** num_payments - 1
#     monthly_payment = principal * (numerator / denominator)
#     return monthly_payment
#
# # Calculate monthly payments for both options
# monthly_payment_1 = calculate_monthly_payment(loan_amount, monthly_rate_1, num_payments_1)
# monthly_payment_2 = calculate_monthly_payment(loan_amount, monthly_rate_2, num_payments_2)
#
# print("MONTHLY PAYMENT CALCULATIONS:")
# print(f"\nOption 1 (15-year at 3.4%):")
# print(f"Monthly Payment: ${monthly_payment_1:,.2f}")
#
# print(f"\nOption 2 (30-year at 2.75%):")
# print(f"Monthly Payment: ${monthly_payment_2:,.2f}")
#
# print(f"\nDifference in Monthly Payment: ${monthly_payment_1 - monthly_payment_2:,.2f}")
# print(f"Option 1 is ${monthly_payment_1 - monthly_payment_2:,.2f} more per month")
# Now let me calculate the total cost of each loan and the total interest paid:
#  Generated Code: # Calculate total payments and interest for both options
#
# # Total Payment Formula: Total = Monthly Payment × Number of Payments
# total_payments_1 = monthly_payment_1 * num_payments_1
# total_payments_2 = monthly_payment_2 * num_payments_2
#
# # Total Interest Formula: Total Interest = Total Payments - Principal
# total_interest_1 = total_payments_1 - loan_amount
# total_interest_2 = total_payments_2 - loan_amount
#
# print("TOTAL COST ANALYSIS:")
# print(f"\nOption 1 (15-year at 3.4%):")
# print(f"  Total Payments = ${monthly_payment_1:,.2f} × {num_payments_1} = ${total_payments_1:,.2f}")
# print(f"  Total Interest = ${total_payments_1:,.2f} - ${loan_amount:,} = ${total_interest_1:,.2f}")
# print(f"  Interest as % of Principal: {(total_interest_1/loan_amount)*100:.1f}%")
#
# print(f"\nOption 2 (30-year at 2.75%):")
# print(f"  Total Payments = ${monthly_payment_2:,.2f} × {num_payments_2} = ${total_payments_2:,.2f}")
# print(f"  Total Interest = ${total_payments_2:,.2f} - ${loan_amount:,} = ${total_interest_2:,.2f}")
# print(f"  Interest as % of Principal: {(total_interest_2/loan_amount)*100:.1f}%")
#
# print(f"\nCOMPARISON:")
# print(f"  Difference in Total Interest: ${total_interest_2 - total_interest_1:,.2f}")
# print(f"  Option 1 saves: ${total_interest_2 - total_interest_1:,.2f} in total interest")
# print(f"  Savings as % of loan amount: {((total_interest_2 - total_interest_1)/loan_amount)*100:.1f}%")
# Let me run a complete analysis in one code block:
#  Generated Code: # Complete Mortgage Analysis
#
# # Given information
# home_value = 500000
# down_payment = 125000
# loan_amount = home_value - down_payment
#
# # Loan Option 1: 15-year term at 3.4% interest
# term_1 = 15
# annual_rate_1 = 3.4
# monthly_rate_1 = annual_rate_1 / 100 / 12
# num_payments_1 = term_1 * 12
#
# # Loan Option 2: 30-year term at 2.75% interest
# term_2 = 30
# annual_rate_2 = 2.75
# monthly_rate_2 = annual_rate_2 / 100 / 12
# num_payments_2 = term_2 * 12
#
# def calculate_monthly_payment(principal, monthly_rate, num_payments):
#     """Calculate monthly mortgage payment using the standard formula"""
#     if monthly_rate == 0:
#         return principal / num_payments
#
#     numerator = monthly_rate * (1 + monthly_rate) ** num_payments
#     denominator = (1 + monthly_rate) ** num_payments - 1
#     monthly_payment = principal * (numerator / denominator)
#     return monthly_payment
#
# # Calculate monthly payments
# monthly_payment_1 = calculate_monthly_payment(loan_amount, monthly_rate_1, num_payments_1)
# monthly_payment_2 = calculate_monthly_payment(loan_amount, monthly_rate_2, num_payments_2)
#
# # Calculate total payments and interest
# total_payments_1 = monthly_payment_1 * num_payments_1
# total_payments_2 = monthly_payment_2 * num_payments_2
# total_interest_1 = total_payments_1 - loan_amount
# total_interest_2 = total_payments_2 - loan_amount
#
# print("=" * 60)
# print("MORTGAGE LOAN COMPARISON ANALYSIS")
# print("=" * 60)
#
# print(f"\nLOAN DETAILS:")
# print(f"Home Value: ${home_value:,}")
# print(f"Down Payment: ${down_payment:,} ({(down_payment/home_value)*100:.1f}%)")
# print(f"Loan Amount: ${loan_amount:,}")
#
# print(f"\n" + "=" * 60)
# print("FORMULAE USED:")
# print("=" * 60)
# print("1. Monthly Payment Formula:")
# print("   M = P × [r(1+r)^n] / [(1+r)^n - 1]")
# print("   Where: M = Monthly payment, P = Principal, r = Monthly rate, n = Number of payments")
# print("\n2. Total Payment Formula:")
# print("   Total Payments = Monthly Payment × Number of Payments")
# print("\n3. Total Interest Formula:")
# print("   Total Interest = Total Payments - Principal Amount")
#
# print(f"\n" + "=" * 60)
# print("OPTION 1: 15-YEAR LOAN AT 3.4%")
# print("=" * 60)
# print(f"Annual Interest Rate: {annual_rate_1}%")
# print(f"Monthly Interest Rate: {monthly_rate_1:.6f}")
# print(f"Number of Payments: {num_payments_1}")
# print(f"Monthly Payment: ${monthly_payment_1:,.2f}")
# print(f"Total Payments: ${total_payments_1:,.2f}")
# print(f"Total Interest: ${total_interest_1:,.2f}")
# print(f"Interest as % of Principal: {(total_interest_1/loan_amount)*100:.1f}%")
#
# print(f"\n" + "=" * 60)
# print("OPTION 2: 30-YEAR LOAN AT 2.75%")
# print("=" * 60)
# print(f"Annual Interest Rate: {annual_rate_2}%")
# print(f"Monthly Interest Rate: {monthly_rate_2:.6f}")
# print(f"Number of Payments: {num_payments_2}")
# print(f"Monthly Payment: ${monthly_payment_2:,.2f}")
# print(f"Total Payments: ${total_payments_2:,.2f}")
# print(f"Total Interest: ${total_interest_2:,.2f}")
# print(f"Interest as % of Principal: {(total_interest_2/loan_amount)*100:.1f}%")
#
# print(f"\n" + "=" * 60)
# print("COMPARISON SUMMARY")
# print("=" * 60)
# print(f"Monthly Payment Difference: ${monthly_payment_1 - monthly_payment_2:,.2f}")
# print(f"  (15-year is ${monthly_payment_1 - monthly_payment_2:,.2f} more per month)")
# print(f"\nTotal Interest Difference: ${total_interest_2 - total_interest_1:,.2f}")
# print(f"  (15-year saves ${total_interest_2 - total_interest_1:,.2f} in total interest)")
# print(f"\nInterest Savings as % of Loan: {((total_interest_2 - total_interest_1)/loan_amount)*100:.1f}%")
# Now let me calculate some additional factors to help you make the decision:
#  Generated Code: # Additional Financial Analysis
#
# print("=" * 60)
# print("ADDITIONAL DECISION FACTORS")
# print("=" * 60)
#
# # Calculate the opportunity cost if you invest the difference
# monthly_difference = monthly_payment_1 - monthly_payment_2
# annual_difference = monthly_difference * 12
#
# print(f"\nOPPORTUNITY COST ANALYSIS:")
# print(f"Extra monthly payment for 15-year loan: ${monthly_difference:,.2f}")
# print(f"Extra annual payment for 15-year loan: ${annual_difference:,.2f}")
#
# # Calculate what the monthly difference could grow to if invested
# # Assuming a 7% annual return (historical stock market average)
# investment_return = 0.07
# monthly_investment_return = investment_return / 12
#
# # Future Value of Annuity Formula: FV = PMT × [((1 + r)^n - 1) / r]
# # Calculate for 15 years (to match the shorter loan term)
# investment_periods = 15 * 12
#
# def future_value_annuity(payment, monthly_rate, periods):
#     """Calculate future value of regular payments invested at given rate"""
#     if monthly_rate == 0:
#         return payment * periods
#     return payment * (((1 + monthly_rate) ** periods - 1) / monthly_rate)
#
# # What if you took the 30-year loan and invested the difference?
# invested_difference = future_value_annuity(monthly_difference, monthly_investment_return, investment_periods)
#
# print(f"\nIF YOU INVEST THE MONTHLY DIFFERENCE:")
# print(f"Formula: FV = PMT × [((1 + r)^n - 1) / r]")
# print(f"Where: PMT = ${monthly_difference:,.2f}, r = {monthly_investment_return:.6f}, n = {investment_periods}")
# print(f"Future Value after 15 years at 7% return: ${invested_difference:,.2f}")
#
# # Net position comparison after 15 years
# print(f"\nNET POSITION AFTER 15 YEARS:")
# print(f"Option 1 (15-year loan): Home is paid off, you own ${home_value:,} home")
# print(f"Option 2 (30-year + investing): You have ${invested_difference:,.2f} invested")
#
# # Calculate remaining mortgage balance after 15 years on 30-year loan
# remaining_balance_15_years = loan_amount
# for i in range(180):  # 15 years of payments
#     interest_payment = remaining_balance_15_years * monthly_rate_2
#     principal_payment = monthly_payment_2 - interest_payment
#     remaining_balance_15_years -= principal_payment
#
# print(f"                                 + Remaining mortgage balance: ${remaining_balance_15_years:,.2f}")
# print(f"                                 = Net worth: ${invested_difference - remaining_balance_15_years:,.2f}")
#
# print(f"\nNET WORTH COMPARISON AFTER 15 YEARS:")
# print(f"15-year loan: ${home_value:,} (free and clear home)")
# print(f"30-year loan + investing: ${invested_difference - remaining_balance_15_years:,.2f}")
# print(f"Difference: ${home_value - (invested_difference - remaining_balance_15_years):,.2f}")
#
# # Break-even analysis
# print(f"\nBREAK-EVEN ANALYSIS:")
# print(f"Interest saved with 15-year loan: ${total_interest_2 - total_interest_1:,.2f}")
# print(f"Potential investment gains: ${invested_difference - (monthly_difference * investment_periods):,.2f}")
# print(f"Net advantage of 15-year loan: ${(total_interest_2 - total_interest_1) - (invested_difference - (monthly_difference * investment_periods)):,.2f}")
# Let me create a final comprehensive analysis with all variables defined:
#  Generated Code: # COMPREHENSIVE MORTGAGE ANALYSIS
#
# import math
#
# # Given information
# home_value = 500000
# down_payment = 125000
# loan_amount = home_value - down_payment
#
# # Loan parameters
# term_1, annual_rate_1 = 15, 3.4  # 15-year at 3.4%
# term_2, annual_rate_2 = 30, 2.75  # 30-year at 2.75%
#
# monthly_rate_1 = annual_rate_1 / 100 / 12
# monthly_rate_2 = annual_rate_2 / 100 / 12
# num_payments_1 = term_1 * 12
# num_payments_2 = term_2 * 12
#
# def calculate_monthly_payment(principal, monthly_rate, num_payments):
#     if monthly_rate == 0:
#         return principal / num_payments
#     numerator = monthly_rate * (1 + monthly_rate) ** num_payments
#     denominator = (1 + monthly_rate) ** num_payments - 1
#     return principal * (numerator / denominator)
#
# # Calculate payments and totals
# monthly_payment_1 = calculate_monthly_payment(loan_amount, monthly_rate_1, num_payments_1)
# monthly_payment_2 = calculate_monthly_payment(loan_amount, monthly_rate_2, num_payments_2)
# total_payments_1 = monthly_payment_1 * num_payments_1
# total_payments_2 = monthly_payment_2 * num_payments_2
# total_interest_1 = total_payments_1 - loan_amount
# total_interest_2 = total_payments_2 - loan_amount
#
# print("=" * 70)
# print("COMPREHENSIVE MORTGAGE LOAN ANALYSIS")
# print("=" * 70)
#
# print("\nFORMULAE USED:")
# print("1. Monthly Payment: M = P × [r(1+r)^n] / [(1+r)^n - 1]")
# print("2. Total Payments: Monthly Payment × Number of Payments")
# print("3. Total Interest: Total Payments - Principal")
# print("4. Future Value of Annuity: FV = PMT × [((1 + r)^n - 1) / r]")
#
# print(f"\n{'':=<70}")
# print("LOAN COMPARISON")
# print("=" * 70)
# print(f"{'Metric':<25} {'15-Year (3.4%)':<20} {'30-Year (2.75%)':<20}")
# print("-" * 70)
# print(f"{'Monthly Payment':<25} ${monthly_payment_1:<19,.2f} ${monthly_payment_2:<19,.2f}")
# print(f"{'Total Payments':<25} ${total_payments_1:<19,.2f} ${total_payments_2:<19,.2f}")
# print(f"{'Total Interest':<25} ${total_interest_1:<19,.2f} ${total_interest_2:<19,.2f}")
# print(f"{'Interest % of Loan':<25} {(total_interest_1/loan_amount)*100:<19.1f}% {(total_interest_2/loan_amount)*100:<19.1f}%")
#
# # Additional analysis
# monthly_difference = monthly_payment_1 - monthly_payment_2
# interest_savings = total_interest_2 - total_interest_1
#
# print(f"\n{'':=<70}")
# print("KEY DIFFERENCES")
# print("=" * 70)
# print(f"Monthly Payment Difference: ${monthly_difference:,.2f} (15-year is higher)")
# print(f"Total Interest Savings (15-year): ${interest_savings:,.2f}")
# print(f"Interest Savings as % of Loan: {(interest_savings/loan_amount)*100:.1f}%")
#
# # Opportunity cost analysis
# investment_return = 0.07
# monthly_investment_return = investment_return / 12
# investment_periods = 15 * 12
#
# def future_value_annuity(payment, monthly_rate, periods):
#     if monthly_rate == 0:
#         return payment * periods
#     return payment * (((1 + monthly_rate) ** periods - 1) / monthly_rate)
#
# invested_difference = future_value_annuity(monthly_difference, monthly_investment_return, investment_periods)
#
# print(f"\n{'':=<70}")
# print("OPPORTUNITY COST ANALYSIS")
# print("=" * 70)
# print(f"If you invest the monthly difference (${monthly_difference:,.2f}) at 7% annual return:")
# print(f"Future value after 15 years: ${invested_difference:,.2f}")
#
# # Calculate remaining balance on 30-year loan after 15 years
# remaining_balance = loan_amount
# for i in range(180):  # 15 years
#     interest_portion = remaining_balance * monthly_rate_2
#     principal_portion = monthly_payment_2 - interest_portion
#     remaining_balance -= principal_portion
#
# print(f"\nAfter 15 years with 30-year loan:")
# print(f"Investment value: ${invested_difference:,.2f}")
# print(f"Remaining mortgage: ${remaining_balance:,.2f}")
# print(f"Net position: ${invested_difference - remaining_balance:,.2f}")
#
# print(f"\nWith 15-year loan after 15 years:")
# print(f"Home value (paid off): ${home_value:,.2f}")
# print(f"Net advantage of 15-year: ${home_value - (invested_difference - remaining_balance):,.2f}")
#
# print(f"\n{'':=<70}")
# print("RECOMMENDATION")
# print("=" * 70)
#
#  Generated Code: # Final recommendation analysis
#
# print("RECOMMENDATION ANALYSIS:")
# print("\nFactors favoring the 15-YEAR LOAN:")
# print("✓ Save $71,887.83 in total interest payments")
# print("✓ Build equity faster - own your home outright in 15 years")
# print("✓ Forced savings through mortgage payments")
# print("✓ Guaranteed return equivalent to 3.4% (your loan rate)")
# print("✓ Peace of mind from being debt-free sooner")
# print("✓ Protection against interest rate risk")
#
# print("\nFactors favoring the 30-YEAR LOAN:")
# print("✓ Lower monthly payment ($1,131.53 less) provides cash flow flexibility")
# print("✓ More money available for other investments or emergencies")
# print("✓ Mortgage interest tax deduction (if applicable)")
# print("✓ Potential to earn higher returns than 2.75% in other investments")
# print("✓ Inflation reduces the real cost of fixed payments over time")
#
# print("\nCONSIDERATIONS FOR YOUR DECISION:")
# print("1. Monthly Budget: Can you comfortably afford $2,662 vs $1,531?")
# print("2. Risk Tolerance: Guaranteed savings vs potential investment gains")
# print("3. Other Financial Goals: Emergency fund, retirement, other investments")
# print("4. Job Security: Higher payment requires more stable income")
# print("5. Tax Situation: Mortgage interest deduction value")
#
# print(f"\nFINAL RECOMMENDATION:")
# print(f"The 15-YEAR LOAN is more suitable if you:")
# print(f"- Can comfortably afford the higher monthly payment")
# print(f"- Prefer guaranteed savings over investment risk")
# print(f"- Want to be debt-free sooner")
# print(f"- Have stable, sufficient income")
#
# print(f"\nThe 30-YEAR LOAN is more suitable if you:")
# print(f"- Need lower monthly payments for cash flow")
# print(f"- Want to invest the difference for potentially higher returns")
# print(f"- Prefer financial flexibility")
# print(f"- Have other high-priority financial goals")
#
# # Calculate payment as percentage of income (rough guideline)
# print(f"\nRULE OF THUMB CHECK:")
# print(f"Financial experts recommend housing costs ≤ 28% of gross monthly income")
# print(f"15-year payment: $2,662 → You need monthly income ≥ ${2662/0.28:,.0f}")
# print(f"30-year payment: $1,531 → You need monthly income ≥ ${1531/0.28:,.0f}")
#
# print(f"\nBOTTOM LINE:")
# print(f"If you can afford the higher payment and prioritize wealth building")
# print(f"through guaranteed savings, choose the 15-year loan.")
# print(f"If you need flexibility or plan to invest elsewhere, choose the 30-year loan.")
# ## Summary
#
# Based on my comprehensive analysis using verified calculations, here are the key findings:
#
# ### **Formulae Used:**
# 1. **Monthly Payment Formula:** M = P × [r(1+r)^n] / [(1+r)^n - 1]
# 2. **Total Payment Formula:** Total Payments = Monthly Payment × Number of Payments
# 3. **Total Interest Formula:** Total Interest = Total Payments - Principal Amount
# 4. **Future Value of Annuity:** FV = PMT × [((1 + r)^n - 1) / r]
#
# ### **Key Financial Metrics:**
#
# | Metric | 15-Year (3.4%) | 30-Year (2.75%) |
# |--------|----------------|------------------|
# | Monthly Payment | $2,662.43 | $1,530.90 |
# | Total Interest | $104,237.76 | $176,125.59 |
# | **Interest Savings** | **$71,887.83 less** | - |
#
# ### **Recommendation:**
#
# **The 15-year loan is more suitable for you if you:**
# - Can comfortably afford the higher monthly payment ($2,662 vs $1,531)
# - Have stable income (need ~$9,507+ monthly gross income)
# - Prefer guaranteed savings over investment risk
# - Want to build equity faster and be debt-free in 15 years
#
# **Key advantages of the 15-year option:**
# - Save $71,887.83 in total interest (19.2% of loan amount)
# - Own your home outright 15 years sooner
# - Guaranteed return equivalent to your 3.4% loan rate
# - Protection against future interest rate increases
#
# The 15-year loan provides a clear financial advantage through substantial interest savings and faster equity building, making it the better choice if you have the financial capacity to handle the higher monthly payment.
